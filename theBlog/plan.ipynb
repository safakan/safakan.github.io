# %%
import pandas as pd

# %%
plan_data = [
    {"Phase": "Phase 0: Database Setup", "Step": "0.1", "Description": "Choose a database service", "Technology": "AWS RDS/PostgreSQL", "Milestone": "Database chosen"},
    {"Phase": "Phase 0: Database Setup", "Step": "0.2", "Description": "Initialize database", "Technology": "SQL/Django ORM", "Milestone": "Database initialized"},
    {"Phase": "Phase 0: Database Setup", "Step": "0.3", "Description": "Test database connection", "Technology": "Django ORM", "Milestone": "Database connected"},
    {"Phase": "Phase 1: Basic Setup", "Step": "1.1", "Description": "Initialize Django project", "Technology": "Django", "Milestone": "Basic working web application"},
    {"Phase": "Phase 1: Basic Setup", "Step": "1.2", "Description": "Setup basic views and URLs", "Technology": "Django", "Milestone": "Basic working web application"},
    {"Phase": "Phase 1: Basic Setup", "Step": "1.3", "Description": "Create basic HTML templates", "Technology": "HTML/CSS", "Milestone": "Basic working web application"},
    {"Phase": "Phase 2: Categories and Basic Blog Posts", "Step": "2.1", "Description": "Create Categories model", "Technology": "Django ORM", "Milestone": "Manually create blog posts with categories"},
    {"Phase": "Phase 2: Categories and Basic Blog Posts", "Step": "2.2", "Description": "Create BlogPost model", "Technology": "Django ORM", "Milestone": "Manually create blog posts with categories"},
    {"Phase": "Phase 2: Categories and Basic Blog Posts", "Step": "2.3", "Description": "Implement Django admin for content management", "Technology": "Django Admin", "Milestone": "Manually create blog posts with categories"},
    {"Phase": "Phase 3: Dynamic Filtering (Categories)", "Step": "3.1", "Description": "Implement JavaScript logic for category-based filtering", "Technology": "JavaScript", "Milestone": "Category-based filtering"},
    {"Phase": "Phase 4: Markdown Support", "Step": "4.1", "Description": "Implement Markdown to HTML conversion", "Technology": "Python/Markdown", "Milestone": "Markdown-based CMS"},
    {"Phase": "Phase 5: Search and Labels", "Step": "5.1", "Description": "Add labels field in BlogPost model", "Technology": "Django ORM", "Milestone": "Basic search functionality"},
    {"Phase": "Phase 5: Search and Labels", "Step": "5.2", "Description": "Implement basic search functionality", "Technology": "JavaScript/Django", "Milestone": "Basic search functionality"},
    {"Phase": "Phase 6: Advanced Search (Topic Modeling)", "Step": "6.1", "Description": "Research and pick a topic modeling algorithm", "Technology": "Python/NLP", "Milestone": "Advanced search functionality"},
    {"Phase": "Phase 6: Advanced Search (Topic Modeling)", "Step": "6.2", "Description": "Train the topic model on your existing blog posts", "Technology": "Python/NLP", "Milestone": "Advanced search functionality"},
    {"Phase": "Phase 6: Advanced Search (Topic Modeling)", "Step": "6.3", "Description": "Integrate the topic model into your search functionality", "Technology": "JavaScript/Django", "Milestone": "Advanced search functionality"}
]

# %%
plan_data_df = pd.DataFrame(plan_data)

# %%
plan_data_df
# Out:
#                                         Phase Step  \
# 0                     Phase 0: Database Setup  0.1
# 1                     Phase 0: Database Setup  0.2
# 2                     Phase 0: Database Setup  0.3
# 3                        Phase 1: Basic Setup  1.1
# 4                        Phase 1: Basic Setup  1.2
# 5                        Phase 1: Basic Setup  1.3
# 6    Phase 2: Categories and Basic Blog Posts  2.1
# 7    Phase 2: Categories and Basic Blog Posts  2.2
# 8    Phase 2: Categories and Basic Blog Posts  2.3
# 9     Phase 3: Dynamic Filtering (Categories)  3.1
# 10                  Phase 4: Markdown Support  4.1
# 11                 Phase 5: Search and Labels  5.1
# 12                 Phase 5: Search and Labels  5.2
# 13  Phase 6: Advanced Search (Topic Modeling)  6.1
# 14  Phase 6: Advanced Search (Topic Modeling)  6.2
# 15  Phase 6: Advanced Search (Topic Modeling)  6.3
#
#                                           Description          Technology  \
# ...

# %%
plan_data_df.to_csv("plan_data.csv")
